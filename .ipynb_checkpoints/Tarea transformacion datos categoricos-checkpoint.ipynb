# %%
import pandas as pd

# %%
adidas = pd.read_csv("adidas.csv")

# %%
adidas.columns
# Out:
# Index(['url', 'name', 'sku', 'selling_price', 'original_price', 'currency',
#        'availability', 'color', 'category', 'source', 'source_website',
#        'breadcrumbs', 'description', 'brand', 'images', 'country', 'language',
#        'average_rating', 'reviews_count', 'crawled_at'],
#       dtype='object')

# %%
datos_categoricos = ['url', 'name', 'sku', 'currency',
       'availability', 'color', 'category', 'source', 'source_website',
       'breadcrumbs', 'description', 'brand', 'images', 'country', 'language',
       ]

# %% [markdown]
# Eliminar los datos que tengan mas del .98%

# %%
target = .97

columnas_validas = []
columnas_arriba_98 = []
columnas_un_nivel = []

for c_ in datos_categoricos:
    x = adidas.loc[ : , [c_] ].drop_duplicates()
    uniquevalues = x.shape[0]
    
    if uniquevalues == 1:
        columnas_un_nivel.append(c_)
    elif (uniquevalues / adidas.shape[0]) > target:
        columnas_arriba_98.append(c_)
    else:
        columnas_validas.append(c_)

# %%
adidas.loc[ : , columnas_arriba_98 ].drop_duplicates()
# Out:
#                                                    url     sku  \
# 0    https://www.adidas.com/us/beach-shorts/FJ5089....  FJ5089
# 1    https://www.adidas.com/us/five-ten-kestrel-lac...  BC0770
# 2    https://www.adidas.com/us/mexico-away-jersey/G...  GC7946
# 3    https://www.adidas.com/us/five-ten-hiangle-pro...  FV4744
# 4    https://www.adidas.com/us/mesh-broken-stripe-p...  GM0239
# ..                                                 ...     ...
# 840  https://www.adidas.com/us/supernova-plus-shoes...  FX2858
# 841  https://www.adidas.com/us/choigo-shoes/H00667....  H00667
# 842  https://www.adidas.com/us/daily-3.0-shoes/GZ77...  GZ7705
# 843  https://www.adidas.com/us/daily-3.0-shoes/GZ77...  GZ7706
# 844  https://www.adidas.com/us/choigo-shoes/FY6503....  FY6503
#
#                                                 images
# 0    https://assets.adidas.com/images/w_600,f_auto,...
# 1    https://assets.adidas.com/images/w_600,f_auto,...
# ...

# %%
adidas.loc[ : , columnas_validas ].drop_duplicates()
# Out:
#                                                 name availability  color  \
# 0                                       Beach Shorts      InStock  Black
# 1          Five Ten Kestrel Lace Mountain Bike Shoes      InStock   Grey
# 2                                 Mexico Away Jersey      InStock  White
# 3    Five Ten Hiangle Pro Competition Climbing Shoes      InStock  Black
# 4                      Mesh Broken-Stripe Polo Shirt      InStock   Blue
# ..                                               ...          ...    ...
# 840                                 Supernova+ Shoes      InStock  White
# 841                                     Choigo Shoes      InStock  White
# 842                                  Daily 3.0 Shoes      InStock  Black
# 843                                  Daily 3.0 Shoes      InStock   Pink
# 844                                     Choigo Shoes      InStock  Black
#
#      category     breadcrumbs  \
# 0    Clothing  Women/Clothing
# ...

# %% [markdown]
# Tratamiento de la columna breadcrumbs

# %%
columnas_validas
# Out:
# ['name', 'availability', 'color', 'category', 'breadcrumbs', 'description']

# %%
frecuencia = adidas.groupby( [ "breadcrumbs" ] , as_index = False ).agg({"sku" : [ "count" ] })

# %%
frecuencia.columns = frecuencia.columns.droplevel(1)

# %%
frecuencia['Porcentage'] = frecuencia['sku'] / adidas.shape[0]

# %%
frecuencia = frecuencia.sort_values( ['Porcentage'] , ascending=False )

# %%
frecuencia #Ya que las primeras 4 filas forman el 71% del dataset podemos tomar a todo lo demas que esta por debajo de ella como Others
# Out:
#               breadcrumbs  sku  Porcentage
# 20         Women/Clothing  176    0.208284
# 21            Women/Shoes  155    0.183432
# 8               Men/Shoes  142    0.168047
# 7            Men/Clothing  128    0.151479
# 5              Kids/Shoes   70    0.082840
# 11        Originals/Shoes   35    0.041420
# 4           Kids/Clothing   30    0.035503
# 18   Training/Accessories   25    0.029586
# 9   Originals/Accessories   22    0.026036
# 19      Women/Accessories   16    0.018935
# 6         Men/Accessories   15    0.017751
# 15           Soccer/Shoes   10    0.011834
# 17             Swim/Shoes    7    0.008284
# 13          Running/Shoes    5    0.005917
# 14     Soccer/Accessories    2    0.002367
# 3        Kids/Accessories    1    0.001183
# 10     Originals/Clothing    1    0.001183
# 1        Essentials/Shoes    1    0.001183
# 12    Running/Accessories    1    0.001183
# 16    Sportswear/Clothing    1    0.001183
# 2          Five Ten/Shoes    1    0.001183
# ...

# %%
frecuencia['breadcrumbs_p'] = 'Others'

# %%
frecuencia
# Out:
#               breadcrumbs  sku  Porcentage breadcrumbs_p
# 20         Women/Clothing  176    0.208284        Others
# 21            Women/Shoes  155    0.183432        Others
# 8               Men/Shoes  142    0.168047        Others
# 7            Men/Clothing  128    0.151479        Others
# 5              Kids/Shoes   70    0.082840        Others
# 11        Originals/Shoes   35    0.041420        Others
# 4           Kids/Clothing   30    0.035503        Others
# 18   Training/Accessories   25    0.029586        Others
# 9   Originals/Accessories   22    0.026036        Others
# 19      Women/Accessories   16    0.018935        Others
# 6         Men/Accessories   15    0.017751        Others
# 15           Soccer/Shoes   10    0.011834        Others
# 17             Swim/Shoes    7    0.008284        Others
# 13          Running/Shoes    5    0.005917        Others
# 14     Soccer/Accessories    2    0.002367        Others
# ...

# %%
frecuencia['breadcrumbs_p'] = frecuencia.apply( lambda r: r['breadcrumbs'] if r['Porcentage'] > 0.10 else r['breadcrumbs_p'] ,axis = 1 )

# %%
frecuencia
# Out:
#               breadcrumbs  sku  Porcentage   breadcrumbs_p
# 20         Women/Clothing  176    0.208284  Women/Clothing
# 21            Women/Shoes  155    0.183432     Women/Shoes
# 8               Men/Shoes  142    0.168047       Men/Shoes
# 7            Men/Clothing  128    0.151479    Men/Clothing
# 5              Kids/Shoes   70    0.082840          Others
# 11        Originals/Shoes   35    0.041420          Others
# 4           Kids/Clothing   30    0.035503          Others
# 18   Training/Accessories   25    0.029586          Others
# 9   Originals/Accessories   22    0.026036          Others
# 19      Women/Accessories   16    0.018935          Others
# 6         Men/Accessories   15    0.017751          Others
# 15           Soccer/Shoes   10    0.011834          Others
# 17             Swim/Shoes    7    0.008284          Others
# 13          Running/Shoes    5    0.005917          Others
# 14     Soccer/Accessories    2    0.002367          Others
# ...

# %%
frecuencia = frecuencia.loc[ : , ['breadcrumbs','breadcrumbs_p'] ]

# %%
adidas.merge( frecuencia , on=['breadcrumbs'] , how='left' )
# Out:
#                                                    url  \
# 0    https://www.adidas.com/us/beach-shorts/FJ5089....
# 1    https://www.adidas.com/us/five-ten-kestrel-lac...
# 2    https://www.adidas.com/us/mexico-away-jersey/G...
# 3    https://www.adidas.com/us/five-ten-hiangle-pro...
# 4    https://www.adidas.com/us/mesh-broken-stripe-p...
# ..                                                 ...
# 840  https://www.adidas.com/us/supernova-plus-shoes...
# 841  https://www.adidas.com/us/choigo-shoes/H00667....
# 842  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 843  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 844  https://www.adidas.com/us/choigo-shoes/FY6503....
#
#                                                 name     sku  selling_price  \
# 0                                       Beach Shorts  FJ5089             40
# 1          Five Ten Kestrel Lace Mountain Bike Shoes  BC0770            150
# ...

# %% [markdown]
# Tratamiento de la columna category

# %%
frecuencia_2 = adidas.groupby( [ "category" ] , as_index = False ).agg({"sku" : [ "count" ] })

# %%
frecuencia_2
# Out:
#       category   sku
#                count
# 0  Accessories    82
# 1     Clothing   337
# 2        Shoes   426

# %%
frecuencia_2.columns = frecuencia_2.columns.droplevel(1)

# %%
frecuencia_2['Porcentaje'] = frecuencia_2['sku'] / adidas.shape[0]

# %%
frecuencia_2 = frecuencia_2.sort_values( ['Porcentaje'] , ascending=False )

# %%
frecuencia_2 #Aqui vamos a poner la fila Accessories como Others ya que es la que tiene menor frecuencia
# Out:
#       category  sku  Porcentaje
# 2        Shoes  426    0.504142
# 1     Clothing  337    0.398817
# 0  Accessories   82    0.097041

# %%
frecuencia_2['category_p'] = 'Others'

# %%
frecuencia_2
# Out:
#       category  sku  Porcentaje category_p
# 2        Shoes  426    0.504142     Others
# 1     Clothing  337    0.398817     Others
# 0  Accessories   82    0.097041     Others

# %%
frecuencia_2['category_p'] = frecuencia_2.apply( lambda r: r['category'] if r['Porcentaje'] > 0.10 else r['category_p'] ,axis = 1 )

# %%
frecuencia_2
# Out:
#       category  sku  Porcentaje category_p
# 2        Shoes  426    0.504142      Shoes
# 1     Clothing  337    0.398817   Clothing
# 0  Accessories   82    0.097041     Others

# %%
frecuencia_2 = frecuencia_2.loc[ : , ['category','category_p'] ]

# %%
adidas.merge( frecuencia_2 , on=['category'] , how='left' )
# Out:
#                                                    url  \
# 0    https://www.adidas.com/us/beach-shorts/FJ5089....
# 1    https://www.adidas.com/us/five-ten-kestrel-lac...
# 2    https://www.adidas.com/us/mexico-away-jersey/G...
# 3    https://www.adidas.com/us/five-ten-hiangle-pro...
# 4    https://www.adidas.com/us/mesh-broken-stripe-p...
# ..                                                 ...
# 840  https://www.adidas.com/us/supernova-plus-shoes...
# 841  https://www.adidas.com/us/choigo-shoes/H00667....
# 842  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 843  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 844  https://www.adidas.com/us/choigo-shoes/FY6503....
#
#                                                 name     sku  selling_price  \
# 0                                       Beach Shorts  FJ5089             40
# 1          Five Ten Kestrel Lace Mountain Bike Shoes  BC0770            150
# ...

# %% [markdown]
# Tramamiento de la columna color

# %%
frecuencia_3 = adidas.groupby( [ "color" ] , as_index = False ).agg({"sku" : [ "count" ] })

# %%
frecuencia_3
# Out:
#          color   sku
#                count
# 0        Beige     6
# 1        Black   187
# 2         Blue   104
# 3        Brown     1
# 4     Burgundy     9
# 5         Gold     3
# 6        Green    59
# 7         Grey    81
# 8        Multi     4
# 9   Multicolor    20
# 10      Orange    11
# 11        Pink    62
# 12      Purple    31
# 13         Red    25
# 14      Silver     1
# 15   Turquoise     2
# 16       White   222
# 17      Yellow    17

# %%
frecuencia_3.columns = frecuencia_3.columns.droplevel(1)

# %%
frecuencia_3['Porcentaje_color'] = frecuencia_3['sku'] / adidas.shape[0]

# %%
frecuencia_3 = frecuencia_3.sort_values( ['Porcentaje_color'] , ascending=False )

# %%
frecuencia_3
# Out:
#          color  sku  Porcentaje_color
# 16       White  222          0.262722
# 1        Black  187          0.221302
# 2         Blue  104          0.123077
# 7         Grey   81          0.095858
# 11        Pink   62          0.073373
# 6        Green   59          0.069822
# 12      Purple   31          0.036686
# 13         Red   25          0.029586
# 9   Multicolor   20          0.023669
# 17      Yellow   17          0.020118
# 10      Orange   11          0.013018
# 4     Burgundy    9          0.010651
# 0        Beige    6          0.007101
# 8        Multi    4          0.004734
# 5         Gold    3          0.003550
# 15   Turquoise    2          0.002367
# 14      Silver    1          0.001183
# 3        Brown    1          0.001183

# %%
frecuencia_3['color_p'] = 'Others'

# %%
frecuencia_3['color_p'] = frecuencia_3.apply( lambda r: r['color'] if r['Porcentaje_color'] > 0.08 else r['color_p'] ,axis = 1 )

# %%
frecuencia_3 # Vamos a poner Other de 8% para abajo
# Out:
#          color  sku  Porcentaje_color color_p
# 16       White  222          0.262722   White
# 1        Black  187          0.221302   Black
# 2         Blue  104          0.123077    Blue
# 7         Grey   81          0.095858    Grey
# 11        Pink   62          0.073373  Others
# 6        Green   59          0.069822  Others
# 12      Purple   31          0.036686  Others
# 13         Red   25          0.029586  Others
# 9   Multicolor   20          0.023669  Others
# 17      Yellow   17          0.020118  Others
# 10      Orange   11          0.013018  Others
# 4     Burgundy    9          0.010651  Others
# 0        Beige    6          0.007101  Others
# 8        Multi    4          0.004734  Others
# 5         Gold    3          0.003550  Others
# 15   Turquoise    2          0.002367  Others
# 14      Silver    1          0.001183  Others
# 3        Brown    1          0.001183  Others

# %%
frecuencia_3 = frecuencia_3.loc[ : , ['color','color_p'] ]

# %%
adidas.merge( frecuencia_3 , on=['color'] , how='left' )
# Out:
#                                                    url  \
# 0    https://www.adidas.com/us/beach-shorts/FJ5089....
# 1    https://www.adidas.com/us/five-ten-kestrel-lac...
# 2    https://www.adidas.com/us/mexico-away-jersey/G...
# 3    https://www.adidas.com/us/five-ten-hiangle-pro...
# 4    https://www.adidas.com/us/mesh-broken-stripe-p...
# ..                                                 ...
# 840  https://www.adidas.com/us/supernova-plus-shoes...
# 841  https://www.adidas.com/us/choigo-shoes/H00667....
# 842  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 843  https://www.adidas.com/us/daily-3.0-shoes/GZ77...
# 844  https://www.adidas.com/us/choigo-shoes/FY6503....
#
#                                                 name     sku  selling_price  \
# 0                                       Beach Shorts  FJ5089             40
# 1          Five Ten Kestrel Lace Mountain Bike Shoes  BC0770            150
# ...
